# %%
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
sc = SparkContext("local", "First App")
print(sc.version)
# 載入檔案
text_file = sc.textFile("yellow.txt")

# word count
counts = text_file.flatMap( lambda line: line.lower().split(" ") ) \
            .map( lambda word: (word, 1) ) \
            .reduceByKey( lambda a, b: a + b ) \
            .sortBy( lambda x: x[1], False )
output = counts.collect()

# just demo to test pyspark is working right
for (word, count) in output:
    print( "%s: %i" % (word, count) )
    
# # Stopping Spark Context
# sc.stop()
ssc = StreamingContext(sc, 20)
# Out:
# 3.1.2
# [Stage 0:>                                                          (0 + 1) / 1]
# default: 7
# purchase_a_sword: 5
# : 1
# 21/08/07 16:48:14 WARN StreamingContext: spark.master should be set as local[n], n > 1 in local mode if you have receivers to get data, otherwise Spark jobs will not get resources to process the received data.

# %%
import sys
from pyspark.streaming.kafka import KafkaUtils
# sc = SparkContext(appName="streamingkafka")
# sc.setLogLevel("WARN") # reduce shell log
# ssc = StreamingContext(sc, 5) 
brokers='192.168.0.104:9092'
# brokers='127.0.0.1:9092'
topic = 'myTopic'


df = sc \
  .readStream \
  .format("kafka") \
  .option("kafka.bootstrap.servers", brokers) \
  .option("subscribe", topic) \
  .load()


# 使用streaming使用直连模式消费kafka 
kafka_streaming_rdd = KafkaUtils.createDirectStream(ssc, [topic], {"metadata.broker.list": brokers})
lines_rdd = kafka_streaming_rdd.map(lambda x: x[1])

counts = lines_rdd.flatMap(lambda line: line.split(" ")) \
    .map(lambda word: (word, 1)) \
    .reduceByKey(lambda a, b: a+b)
k_v = {}

def result(y):
    global k_v
    taken = y.take(6)
    for record in taken[:6]:
        print(record,'#')
        if record[0] not in k_v:
            k_v[record[0] ] = record[1]
        else:
            k_v[record[0] ] += record[1]
        print('k_v=', k_v)

    if 'default' in k_v and 'purchased_sword' in k_v and 'c' in k_v:
        
        return y

rdd = wordCounts.foreachRDD(result)


ssc.start()
ssc.awaitTermination()


# save to existed hdfs
# https://stackoverflow.com/questions/44290548/how-to-write-pyspark-dataframe-to-hdfs-and-then-how-to-read-it-back-into-datafra
df.write.save('/target/hdfs_path/', format='parquet', mode='append') ## df is an existing DataFrame object.
# Out:
# ---------- <pyspark.streaming.dstream.TransformedDStream object at 0x7fbcf81c4a60>
# ...
# -------------------------------------------
# Time: 2021-08-07 16:48:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-07 16:48:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-08-07 16:48:40
# -------------------------------------------
# ('purchased_sword', 3)
#
# -------------------------------------------
# Time: 2021-08-07 16:48:40
# -------------------------------------------
# ('purchased_sword', 3)
#
# ('purchased_sword', 3) #
# k_v= {'purchased_sword': 3}
# -------------------------------------------
# Time: 2021-08-07 16:49:00
# -------------------------------------------
# ('default', 9)
#
# -------------------------------------------
# Time: 2021-08-07 16:49:00
# -------------------------------------------
# ('default', 9)
#
# ('default', 9) #
# ...

# %%
'''
from operator import add
lines = ssc.textFileStream('logfile')
words = lines.flatMap(lambda line: line.split(' '))
print('-'*10, words)
wordCounts = words.map(lambda x : (x,1)).reduceByKey(add)
print(wordCounts)
wordCounts.pprint()
wordCounts.pprint()

k_v = {}

def result(y):
    global k_v
    taken = y.take(6)
    for record in taken[:6]:
        print(record,'#')
        if record[0] not in k_v:
            k_v[record[0] ] = record[1]
        else:
            k_v[record[0] ] += record[1]
        print('k_v=', k_v)

    if 'default' in k_v and 'purchased_sword' in k_v and 'c' in k_v:
        
        return y

rdd = wordCounts.foreachRDD(result)



ssc.start()
ssc.awaitTermination()
'''


df.write.save('/target/hdfs_path/', format='parquet', mode='append') ## df is an existing DataFrame object.
# Stopping Spark Context
sc.stop()
