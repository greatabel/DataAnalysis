# %%
from __future__ import print_function
import pyspark
from pyspark import SparkContext
from pyspark.sql import SQLContext, DataFrame
from pyspark.sql.functions import desc, mean

# %%
sc = SparkContext.getOrCreate()
# sc = SparkContext() 
sc
# Out:
# <SparkContext master=yarn appName=PySparkShell>

# %%
sqlContext = SQLContext(sc)
#df = sqlContext.read.csv('/data/ProjectDatasetTwitter/statuses.log.2014-12-04.gz') # about 15 minutes to run 
df = sqlContext.read.json('/data/ProjectDatasetTwitter/statuses.log.2014-12-04.gz')

# %%
print(df.show())
# Out:
# +------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+--------------------+------+--------------------+--------------------+-------------+---------+--------------------+---------------------+
# |contributors|coordinates|          created_at|              delete|            entities|   extended_entities|favorite_count|favorited|filter_level| geo|                id|            id_str|in_reply_to_screen_name|in_reply_to_status_id|in_reply_to_status_id_str|in_reply_to_user_id|in_reply_to_user_id_str|lang|place|possibly_sensitive|retweet_count|retweeted|    retweeted_status|scopes|              source|                text| timestamp_ms|truncated|                user|withheld_in_countries|
# +------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+--------------------+------+--------------------+--------------------+-------------+---------+--------------------+---------------------+
# |        null|       null|                null|[[564282450584576...|                null|                null|          null|     null|        null|null|              null|              null|                   null|                 null|                     null|               null|                   null|null| null|              null|         null|     null|                null|  null|                null|                null|         null|     null|                null|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312499638272|540279312499638272|                   null|                 null|                     null|               null|                   null| und| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://t...|RT @jonyleal2011:...|1417647600661|    false|[false,Wed Nov 26...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312495435776|540279312495435776|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|[null,null,Tue De...|  null|<a href="http://t...|RT @taylorswift13...|1417647600660|    false|[false,Sun Sep 21...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312495431680|540279312495431680|                   null|                 null|                     null|               null|                   null|  fr| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://t...|RT @MOphely: Des ...|1417647600660|    false|[false,Sun Mar 10...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),W...|[WrappedArray([pi...|             0|    false|      medium|null|540279312520581120|540279312520581120|                   null|                 null|                     null|               null|                   null|  fr| null|             false|            0|    false|[null,null,Sun No...|  null|<a href="http://t...|RT @tweetsdamour_...|1417647600666|    false|[false,Sat Jan 12...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),W...|[WrappedArray([pi...|             0|    false|      medium|null|540279312503832576|540279312503832576|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://t...|RT @NightLifeFail...|1417647600662|    false|[false,Thu Oct 23...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312508014592|540279312508014592|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://t...|RT @JohnMayer: A ...|1417647600663|    false|[false,Tue Jul 27...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312512196608|540279312512196608|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|[null,null,Mon No...|  null|<a href="http://t...|RT @gamer55634: F...|1417647600664|    false|[false,Mon Dec 27...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312499613696|540279312499613696|                   null|                 null|                     null|               null|                   null| und| null|             false|            0|    false|                null|  null|<a href="http://t...|              00:00.|1417647600661|    false|[false,Wed Jan 04...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312516399104|540279312516399104|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|                null|  null|<a href="http://t...|Watching django o...|1417647600665|    false|[false,Fri Jul 04...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312487022592|540279312487022592|                   null|                 null|                     null|               null|                   null|  es| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://a...|RT @LeoNoSoy_: Tí...|1417647600658|    false|[false,Sat Jun 21...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312491216896|540279312491216896|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|                null|  null|<a href="http://t...|I truly hope this...|1417647600659|    false|[false,Sun Sep 15...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray([Wr...|                null|             0|    false|      medium|null|540279312499617792|540279312499617792|                   null|                 null|                     null|               null|                   null|  fr| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://q...|RT @laurencelabat...|1417647600661|    false|[false,Mon Sep 01...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312512212992|540279312512212992|                   null|                 null|                     null|               null|                   null|  en| null|             false|            0|    false|[null,null,Sat Oc...|  null|<a href="http://t...|RT @FvckShann: @Z...|1417647600664|    false|[false,Fri Oct 10...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312487030784|540279312487030784|             ADAMATOMIC|   540277704839663617|       540277704839663617|           70587360|               70587360|  en| null|             false|            0|    false|                null|  null|<a href="http://t...|@ADAMATOMIC @xiot...|1417647600658|    false|[false,Thu Apr 30...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312491229186|540279312491229186|               jkirby_1|   540279088418938881|       540279088418938881|          519881407|              519881407|  en| null|             false|            0|    false|                null|  null|<a href="http://t...|@jkirby_1 final o...|1417647600659|    false|[false,Mon Oct 08...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312499625984|540279312499625984|                Selay53|   540278777515765760|       540278777515765760|         2363150036|             2363150036|  tr| null|             false|            0|    false|                null|  null|<a href="http://t...|@Selay53 o vakit ...|1417647600661|    false|[false,Thu Jun 21...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312503824384|540279312503824384|                   null|                 null|                     null|               null|                   null|  es| null|             false|            0|    false|                null|  null|<a href="http://t...|Me jode poner una...|1417647600662|    false|[false,Sat Apr 30...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray(),n...|                null|             0|    false|      medium|null|540279312491245568|540279312491245568|        BritishTraveler|   540128950866173952|       540128950866173952|           48869954|               48869954|  en| null|             false|            0|    false|                null|  null|<a href="http://t...|Can't wait to see...|1417647600659|    false|[false,Tue Dec 08...|                 null|
# |        null|       null|Wed Dec 03 23:00:...|                null|[WrappedArray([Wr...|                null|             0|    false|      medium|null|540279312503812096|540279312503812096|                   null|                 null|                     null|               null|                   null|  pt| null|             false|            0|    false|[null,null,Wed De...|  null|<a href="http://t...|RT @LOBO54R: O PT...|1417647600662|    false|[false,Mon Jan 27...|                 null|
# +------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+--------------------+------+--------------------+--------------------+-------------+---------+--------------------+---------------------+
# only showing top 20 rows
#
# None

# %%
df.show(n=20, truncate=False)
# Out:
# +------------+-----------+------------------------------+-------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |contributors|coordinates|created_at                    |delete                                                                   |entities                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |extended_entities                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |favorite_count|favorited|filter_level|geo |id                |id_str            |in_reply_to_screen_name|in_reply_to_status_id|in_reply_to_status_id_str|in_reply_to_user_id|in_reply_to_user_id_str|lang|place|possibly_sensitive|retweet_count|retweeted|retweeted_status                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# +------------+-----------+------------------------------+-------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |null        |null       |null                          |[[56428245058457600,56428245058457600,276700097,276700097],1417647600084]|null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |null          |null     |null        |null|null              |null              |null                   |null                 |null                     |null               |null                   |null|null |null              |null         |null     |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# |null        |null       |Wed Dec 03 23:00:00 +0000 2014|null                                                                     |[WrappedArray(),null,WrappedArray(),WrappedArray(),WrappedArray(),WrappedArray([1055383434,1055383434,WrappedArray(3, 16),jonatan leal,jonyleal2011], [2169220070,2169220070,WrappedArray(18, 27),betül şahin,betl1000])]                                                                                                                                                                                                                                                                                                                                         |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |0             |false    |medium      |null|540279312499638272|540279312499638272|null                   |null                 |null                     |null               |null                   |und |null |false             |0            |false    |[null,null,Wed Dec 03 22:21:27 +0000 2014,[WrappedArray(),null,WrappedArray(),WrappedArray(),WrappedArray(),WrappedArray([2169220070,2169220070,WrappedArray(0, 9),betül şahin,betl1000])],null,0,false,low,null,540269609174441985,540269609174441985,betl1000,null,null,2169220070,2169220070,und,null,false,1,false,null,<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>,@betl1000,false,[false,Wed Jan 02 15:35:38 +0000 2013,true,true,null,6,null,230,null,1302,false,1055383434,1055383434,false,pt,0,,jonatan leal,null,C0DEED,http://abs.twimg.com/images/themes/theme1/bg.png,https://abs.twimg.com/images/themes/theme1/bg.png,false,null,http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png,https://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png,0084B4,C0DEED,DDEEF6,333333,true,false,jonyleal2011,12,null,null,null,false],null]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# |null        |null       |Wed Dec 03 23:00:00 +0000 2014|null                                                                     |[WrappedArray(),null,WrappedArray(),WrappedArray(),WrappedAr
a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>,Fuck -.-,false,[false,Thu Sep 13 00:07:05 +0000 2012,true,false,null,250,null,139,null,86,false,820572206,820572206,false,en,0,,robertson,null,C0DEED,http://abs.twimg.com/images/themes/theme1/bg.png,https://abs.twimg.com/images/themes/theme1/bg.png,false,https://pbs.twimg.com/profile_banners/820572206/1383522511,http://pbs.twimg.com/profile_images/378800000581601656/27de14d78a7e59e05b8932d15139a607_normal.jpeg,https://pbs.twimg.com/profile_images/378800000581601656/27de14d78a7e59e05b8932d15139a607_normal.jpeg,0084B4,C0DEED,DDEEF6,333333,true,false,gamer55634,403,null,null,null,false],null]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# ...
# |null        |null       |Wed Dec 03 23:00:00 +0000 2014|null                                                                     |[WrappedArray(),null,WrappedArray(),WrappedArray(),WrappedArray(),WrappedArray([48869954,48869954,WrappedArray(50, 66),Steve Langley,BritishTraveler])]                                                                                                                                                                                                                                                                                                                                                                                                           |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |0             |false    |medium      |null|540279312491245568|540279312491245568|BritishTraveler        |540128950866173952   |540128950866173952       |48869954           |48869954               |en  |null |false             |0            |false    |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# |null        |null       |Wed Dec 03 23:00:00 +0000 2014|null                                                                     |[WrappedArray([WrappedArray(105, 120),SouContraPLN36]),null,WrappedArray(),WrappedArray(),WrappedArray(),WrappedArray([534677741,534677741,WrappedArray(3, 11),ricardo lobo,LOBO54R])]                                                                                                                                                                                                                                                                                                                                                                            |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |0             |false    |medium      |null|540279312503812096|540279312503812096|null                   |null                 |null                     |null               |null                   |pt  |null |false             |0            |false    |[null,null,Wed Dec 03 22:40:53 +0000 2014,[WrappedArray([WrappedArray(92, 107),SouContraPLN36]),null,WrappedArray(),WrappedArray(),WrappedArray(),WrappedArray()],null,7,false,low,null,540274503033823232,540274503033823232,null,null,null,null,null,pt,null,true,12,false,null,<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>,O PT segue marcado como partido da mentira e do ataque. Não quer oposição e nem democracia. #SouContraPLN36,false,[false,Fri Mar 23 20:06:43 +0000 2012,false,false,null,3535,null,968,null,2000,true,534677741,534677741,false,pt,5,brasil - sao paulo,ricardo lobo,null,3B94D9,http://pbs.twimg.com/profile_background_images/514895324880453632/gTM0kKV-.jpeg,https://pbs.twimg.com/profile_background_images/514895324880453632/gTM0kKV-.jpeg,true,https://pbs.twimg.com/profile_banners/534677741/1413242055,http://pbs.twimg.com/profile_images/519296823060492288/I7J8advo_normal.png,https://pbs.twimg.com/profile_images/519296823060492288/I7J8advo_normal.png,3B94D9,FFFFFF,FFF7CC,0C3E53,true,false,LOBO54R,24196,Santiago,null,-10800,false],null]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ...
# +------------+-----------+------------------------------+-------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------+---------+------------+----+------------------+------------------+-----------------------+---------------------+-------------------------+-------------------+-----------------------+----+-----+------------------+-------------+---------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 20 rows

# %%
df.printSchema()

mylist = df.head(5) 
for item in mylist:
    print('row=', item, '\n')
# Out:
# root
#  |-- contributors: string (nullable = true)
#  |-- coordinates: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- delete: struct (nullable = true)
#  |    |-- status: struct (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- user_id: long (nullable = true)
#  |    |    |-- user_id_str: string (nullable = true)
#  |    |-- timestamp_ms: string (nullable = true)
#  |-- entities: struct (nullable = true)
#  |    |-- hashtags: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- symbols: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- text: string (nullable = true)
#  |    |-- trends: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- urls: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- user_mentions: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- screen_name: string (nullable = true)
#  |-- extended_entities: struct (nullable = true)
#  |    |-- media: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |-- favorite_count: long (nullable = true)
#  |-- favorited: boolean (nullable = true)
#  |-- filter_level: string (nullable = true)
#  |-- geo: struct (nullable = true)
#  |    |-- coordinates: array (nullable = true)
#  |    |    |-- element: double (containsNull = true)
#  |    |-- type: string (nullable = true)
#  |-- id: long (nullable = true)
#  |-- id_str: string (nullable = true)
#  |-- in_reply_to_screen_name: string (nullable = true)
#  |-- in_reply_to_status_id: long (nullable = true)
#  |-- in_reply_to_status_id_str: string (nullable = true)
#  |-- in_reply_to_user_id: long (nullable = true)
#  |-- in_reply_to_user_id_str: string (nullable = true)
#  |-- lang: string (nullable = true)
#  |-- place: struct (nullable = true)
#  |    |-- attributes: struct (nullable = true)
#  |    |    |-- street_address: string (nullable = true)
#  |    |-- bounding_box: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- country: string (nullable = true)
#  |    |-- country_code: string (nullable = true)
#  |    |-- full_name: string (nullable = true)
#  |    |-- id: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- place_type: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- possibly_sensitive: boolean (nullable = true)
#  |-- retweet_count: long (nullable = true)
#  |-- retweeted: boolean (nullable = true)
#  |-- retweeted_status: struct (nullable = true)
#  |    |-- contributors: array (nullable = true)
#  |    |    |-- element: long (containsNull = true)
#  |    |-- coordinates: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- entities: struct (nullable = true)
#  |    |    |-- hashtags: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- symbols: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |-- trends: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- urls: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- user_mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- screen_name: string (nullable = true)
#  |    |-- extended_entities: struct (nullable = true)
#  |    |    |-- media: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- display_url: string (nullable = true)
#  |    |    |    |    |-- expanded_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- id_str: string (nullable = true)
#  |    |    |    |    |-- indices: array (nullable = true)
#  |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |-- media_url: string (nullable = true)
#  |    |    |    |    |-- media_url_https: string (nullable = true)
#  |    |    |    |    |-- sizes: struct (nullable = true)
#  |    |    |    |    |    |-- large: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- medium: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- small: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |    |-- thumb: struct (nullable = true)
#  |    |    |    |    |    |    |-- h: long (nullable = true)
#  |    |    |    |    |    |    |-- resize: string (nullable = true)
#  |    |    |    |    |    |    |-- w: long (nullable = true)
#  |    |    |    |    |-- source_status_id: long (nullable = true)
#  |    |    |    |    |-- source_status_id_str: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |-- favorite_count: long (nullable = true)
#  |    |-- favorited: boolean (nullable = true)
#  |    |-- filter_level: string (nullable = true)
#  |    |-- geo: struct (nullable = true)
#  |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |-- element: double (containsNull = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- in_reply_to_screen_name: string (nullable = true)
#  |    |-- in_reply_to_status_id: long (nullable = true)
#  |    |-- in_reply_to_status_id_str: string (nullable = true)
#  |    |-- in_reply_to_user_id: long (nullable = true)
#  |    |-- in_reply_to_user_id_str: string (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- place: struct (nullable = true)
#  |    |    |-- bounding_box: struct (nullable = true)
#  |    |    |    |-- coordinates: array (nullable = true)
#  |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |-- element: array (containsNull = true)
#  |    |    |    |    |    |    |-- element: double (containsNull = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- country: string (nullable = true)
#  |    |    |-- country_code: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- place_type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- possibly_sensitive: boolean (nullable = true)
#  |    |-- retweet_count: long (nullable = true)
#  |    |-- retweeted: boolean (nullable = true)
#  |    |-- scopes: struct (nullable = true)
#  |    |    |-- followers: boolean (nullable = true)
#  |    |    |-- place_ids: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |-- source: string (nullable = true)
#  |    |-- text: string (nullable = true)
#  |    |-- truncated: boolean (nullable = true)
#  |    |-- user: struct (nullable = true)
#  |    |    |-- contributors_enabled: boolean (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_profile: boolean (nullable = true)
#  |    |    |-- default_profile_image: boolean (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- favourites_count: long (nullable = true)
#  |    |    |-- follow_request_sent: string (nullable = true)
#  |    |    |-- followers_count: long (nullable = true)
#  |    |    |-- following: string (nullable = true)
#  |    |    |-- friends_count: long (nullable = true)
#  |    |    |-- geo_enabled: boolean (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- id_str: string (nullable = true)
#  |    |    |-- is_translator: boolean (nullable = true)
#  |    |    |-- lang: string (nullable = true)
#  |    |    |-- listed_count: long (nullable = true)
#  |    |    |-- location: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- notifications: string (nullable = true)
#  |    |    |-- profile_background_color: string (nullable = true)
#  |    |    |-- profile_background_image_url: string (nullable = true)
#  |    |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |    |-- profile_background_tile: boolean (nullable = true)
#  |    |    |-- profile_banner_url: string (nullable = true)
#  |    |    |-- profile_image_url: string (nullable = true)
#  |    |    |-- profile_image_url_https: string (nullable = true)
#  |    |    |-- profile_link_color: string (nullable = true)
#  |    |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |    |-- profile_text_color: string (nullable = true)
#  |    |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |    |-- protected: boolean (nullable = true)
#  |    |    |-- screen_name: string (nullable = true)
#  |    |    |-- statuses_count: long (nullable = true)
#  |    |    |-- time_zone: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- utc_offset: long (nullable = true)
#  |    |    |-- verified: boolean (nullable = true)
#  |    |-- withheld_in_countries: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- scopes: struct (nullable = true)
#  |    |-- place_ids: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |-- source: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- timestamp_ms: string (nullable = true)
#  |-- truncated: boolean (nullable = true)
#  |-- user: struct (nullable = true)
#  |    |-- contributors_enabled: boolean (nullable = true)
#  |    |-- created_at: string (nullable = true)
#  |    |-- default_profile: boolean (nullable = true)
#  |    |-- default_profile_image: boolean (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- favourites_count: long (nullable = true)
#  |    |-- follow_request_sent: string (nullable = true)
#  |    |-- followers_count: long (nullable = true)
#  |    |-- following: string (nullable = true)
#  |    |-- friends_count: long (nullable = true)
#  |    |-- geo_enabled: boolean (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- id_str: string (nullable = true)
#  |    |-- is_translator: boolean (nullable = true)
#  |    |-- lang: string (nullable = true)
#  |    |-- listed_count: long (nullable = true)
#  |    |-- location: string (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- notifications: string (nullable = true)
#  |    |-- profile_background_color: string (nullable = true)
#  |    |-- profile_background_image_url: string (nullable = true)
#  |    |-- profile_background_image_url_https: string (nullable = true)
#  |    |-- profile_background_tile: boolean (nullable = true)
#  |    |-- profile_banner_url: string (nullable = true)
#  |    |-- profile_image_url: string (nullable = true)
#  |    |-- profile_image_url_https: string (nullable = true)
#  |    |-- profile_link_color: string (nullable = true)
#  |    |-- profile_sidebar_border_color: string (nullable = true)
#  |    |-- profile_sidebar_fill_color: string (nullable = true)
#  |    |-- profile_text_color: string (nullable = true)
#  |    |-- profile_use_background_image: boolean (nullable = true)
#  |    |-- protected: boolean (nullable = true)
#  |    |-- screen_name: string (nullable = true)
#  |    |-- statuses_count: long (nullable = true)
#  |    |-- time_zone: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |    |-- utc_offset: long (nullable = true)
#  |    |-- verified: boolean (nullable = true)
#  |-- withheld_in_countries: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#
# row= Row(contributors=None, coordinates=None, created_at=None, delete=Row(status=Row(id=56428245058457600, id_str='56428245058457600', user_id=276700097, user_id_str='276700097'), timestamp_ms='1417647600084'), entities=None, extended_entities=None, favorite_count=None, favorited=None, filter_level=None, geo=None, id=None, id_str=None, in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang=None, place=None, possibly_sensitive=None, retweet_count=None, retweeted=None, retweeted_status=None, scopes=None, source=None, text=None, timestamp_ms=None, truncated=None, user=None, withheld_in_countries=None)
#
# row= Row(contributors=None, coordinates=None, created_at='Wed Dec 03 23:00:00 +0000 2014', delete=None, entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[], user_mentions=[Row(id=1055383434, id_str='1055383434', indices=[3, 16], name='jonatan leal', screen_name='jonyleal2011'), Row(id=2169220070, id_str='2169220070', indices=[18, 27], name='betül şahin', screen_name='betl1000')]), extended_entities=None, favorite_count=0, favorited=False, filter_level='medium', geo=None, id=540279312499638272, id_str='540279312499638272', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='und', place=None, possibly_sensitive=False, retweet_count=0, retweeted=False, retweeted_status=Row(contributors=None, coordinates=None, created_at='Wed Dec 03 22:21:27 +0000 2014', entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[], user_mentions=[Row(id=2169220070, id_str='2169220070', indices=[0, 9], name='betül şahin', screen_name='betl1000')]), extended_entities=None, favorite_count=0, favorited=False, filter_level='low', geo=None, id=540269609174441985, id_str='540269609174441985', in_reply_to_screen_name='betl1000', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=2169220070, in_reply_to_user_id_str='2169220070', lang='und', place=None, possibly_sensitive=False, retweet_count=1, retweeted=False, scopes=None, source='<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', text='@betl1000', truncated=False, user=Row(contributors_enabled=False, created_at='Wed Jan 02 15:35:38 +0000 2013', default_profile=True, default_profile_image=True, description=None, favourites_count=6, follow_request_sent=None, followers_count=230, following=None, friends_count=1302, geo_enabled=False, id=1055383434, id_str='1055383434', is_translator=False, lang='pt', listed_count=0, location='', name='jonatan leal', notifications=None, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_banner_url=None, profile_image_url='http://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', profile_image_url_https='https://abs.twimg.com/sticky/default_profile_images/default_profile_0_normal.png', profile_link_color='0084B4', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=True, protected=False, screen_name='jonyleal2011', statuses_count=12, time_zone=None, url=None, utc_offset=None, verified=False), withheld_in_countries=None), scopes=None, source='<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', text='RT @jonyleal2011: @betl1000', timestamp_ms='1417647600661', truncated=False, user=Row(contributors_enabled=False, created_at='Wed Nov 26 00:06:52 +0000 2014', default_profile=True, default_profile_image=False, description=None, favourites_count=1, follow_request_sent=None, followers_count=93, following=None, friends_count=480, geo_enabled=True, id=2892757048, id_str='2892757048', is_translator=False, lang='pt', listed_count=0, location='', name='Carlos Pinto', notifications=None, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png', profile_background_image_url_https='https://abs.twimg.com/images/themes/theme1/bg.png', profile_background_tile=False, profile_banner_url=None, profile_image_url='http://pbs.twimg.com/profile_images/537397216454119424/7g43-5fZ_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/537397216454119424/7g43-5fZ_normal.jpeg', profile_link_color='0084B4', profile_sidebar_border_color='C0DEED', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profi ...
#
# row= Row(contributors=None, coordinates=None, created_at='Wed Dec 03 23:00:00 +0000 2014', delete=None, entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[Row(display_url='instagram.com/p/wHwCJXjvDv/', expanded_url='http://instagram.com/p/wHwCJXjvDv/', indices=[47, 69], url='http://t.co/UBETT26zyY')], user_mentions=[Row(id=17919972, id_str='17919972', indices=[3, 17], name='Taylor Swift', screen_name='taylorswift13')]), extended_entities=None, favorite_count=0, favorited=False, filter_level='medium', geo=None, id=540279312495435776, id_str='540279312495435776', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='en', place=None, possibly_sensitive=False, retweet_count=0, retweeted=False, retweeted_status=Row(contributors=None, coordinates=None, created_at='Tue Dec 02 22:28:21 +0000 2014', entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[Row(display_url='instagram.com/p/wHwCJXjvDv/', expanded_url='http://instagram.com/p/wHwCJXjvDv/', indices=[28, 50], url='http://t.co/UBETT26zyY')], user_mentions=[]), extended_entities=None, favorite_count=13349, favorited=False, filter_level='low', geo=None, id=539908960803774464, id_str='539908960803774464', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='en', place=None, possibly_sensitive=False, retweet_count=7198, retweeted=False, scopes=None, source='<a href="http://instagram.com" rel="nofollow">Instagram</a>', text='Tuesday was totally casual. http://t.co/UBETT26zyY', truncated=False, user=Row(contributors_enabled=False, created_at='Sat Dec 06 10:10:54 +0000 2008', default_profile=False, default_profile_image=False, description='Born in 1989.', favourites_count=179, follow_request_sent=None, followers_count=47757815, following=None, friends_count=148, geo_enabled=False, id=17919972, id_str='17919972', is_translator=False, lang='en', listed_count=118042, location='', name='Taylor Swift', notifications=None, profile_background_color='C0DEED', profile_background_image_url='http://pbs.twimg.com/profile_background_images/687293757/6d2ec27f32fa8cc2fcb7e6a9eada9945.jpeg', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/687293757/6d2ec27f32fa8cc2fcb7e6a9eada9945.jpeg', profile_background_tile=False, profile_banner_url='https://pbs.twimg.com/profile_banners/17919972/1409286315', profile_image_url='http://pbs.twimg.com/profile_images/505200807503867904/osJXmYRl_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/505200807503867904/osJXmYRl_normal.jpeg', profile_link_color='0084B4', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='DDEEF6', profile_text_color='333333', profile_use_background_image=False, protected=False, screen_name='taylorswift13', statuses_count=2986, time_zone=None, url='http://www.taylorswift.com', utc_offset=None, verified=True), withheld_in_countries=None), scopes=None, source='<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', text='RT @taylorswift13: Tuesday was totally casual. http://t.co/UBETT26zyY', timestamp_ms='1417647600660', truncated=False, user=Row(contributors_enabled=False, created_at='Sun Sep 21 14:21:08 +0000 2014', default_profile=True, default_profile_image=False, description='Side project done by @jobellegulian8 ❤️ All you need to do to be my friend is like me. -@taylorswift13 • I met @CHVRCHES on 10.7.14 10/22/14 I was on @Q1075', favourites_count=3948, follow_request_sent=None, followers_count=420, following=None, friends_count=1311, geo_enabled=False, id=2778989571, id_str='2778989571', is_translator=False, lang='en', listed_count=3, location='901 ', name='Most Likely to Tweet', notifications=None, profile_background_color='C0DEED', profile_background_image_url='http://abs.twimg.com/images/themes/theme1/bg.png',  ...
#
# row= Row(contributors=None, coordinates=None, created_at='Wed Dec 03 23:00:00 +0000 2014', delete=None, entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[], user_mentions=[Row(id=361800564, id_str='361800564', indices=[3, 11], name='Ophé ☾☼', screen_name='MOphely')]), extended_entities=None, favorite_count=0, favorited=False, filter_level='medium', geo=None, id=540279312495431680, id_str='540279312495431680', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='fr', place=None, possibly_sensitive=False, retweet_count=0, retweeted=False, retweeted_status=Row(contributors=None, coordinates=None, created_at='Wed Dec 03 22:49:46 +0000 2014', entities=Row(hashtags=[], media=None, symbols=[], trends=[], urls=[], user_mentions=[]), extended_entities=None, favorite_count=1, favorited=False, filter_level='low', geo=None, id=540276736291000320, id_str='540276736291000320', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='fr', place=None, possibly_sensitive=False, retweet_count=1, retweeted=False, scopes=None, source='<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', text='Des fois je parle tranquille avec Morgane et elle me sort comme ça des punchlines de caillera 😂', truncated=False, user=Row(contributors_enabled=False, created_at='Thu Aug 25 10:46:38 +0000 2011', default_profile=False, default_profile_image=False, description='19ans, etudiante a Lille 3 . Les twins @_morganem ❤️ IG➡️ophely_18 ❕snapchat : ophely-18 !', favourites_count=1129, follow_request_sent=None, followers_count=278, following=None, friends_count=179, geo_enabled=True, id=361800564, id_str='361800564', is_translator=False, lang='fr', listed_count=1, location='Lille (59)', name='Ophé ☾☼', notifications=None, profile_background_color='131516', profile_background_image_url='http://pbs.twimg.com/profile_background_images/510163414098796544/PiwzPUE7.jpeg', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/510163414098796544/PiwzPUE7.jpeg', profile_background_tile=True, profile_banner_url='https://pbs.twimg.com/profile_banners/361800564/1416260627', profile_image_url='http://pbs.twimg.com/profile_images/536089572351148032/uYptEhQz_normal.jpeg', profile_image_url_https='https://pbs.twimg.com/profile_images/536089572351148032/uYptEhQz_normal.jpeg', profile_link_color='5C0099', profile_sidebar_border_color='FFFFFF', profile_sidebar_fill_color='E3E2DE', profile_text_color='634047', profile_use_background_image=True, protected=False, screen_name='MOphely', statuses_count=42789, time_zone=None, url='https://www.facebook.com/ophelie.martin.9?ref=tn_tnmn', utc_offset=None, verified=False), withheld_in_countries=None), scopes=None, source='<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', text='RT @MOphely: Des fois je parle tranquille avec Morgane et elle me sort comme ça des punchlines de caillera 😂', timestamp_ms='1417647600660', truncated=False, user=Row(contributors_enabled=False, created_at='Sun Mar 10 21:37:37 +0000 2013', default_profile=False, default_profile_image=False, description='From Lille. #OTF', favourites_count=578, follow_request_sent=None, followers_count=568, following=None, friends_count=71, geo_enabled=True, id=1257998982, id_str='1257998982', is_translator=False, lang='fr', listed_count=2, location='', name="Almighty Chris A'", notifications=None, profile_background_color='C0DEED', profile_background_image_url='http://pbs.twimg.com/profile_background_images/477173860060495872/PKrULrST.jpeg', profile_background_image_url_https='https://pbs.twimg.com/profile_background_images/477173860060495872/PKrULrST.jpeg', profile_background_tile=True, profile_banner_url='https://pbs.twimg.com/profile_banners/1257998982/1402601323', profile_image_url=' ...
#
# row= Row(contributors=None, coordinates=None, created_at='Wed Dec 03 23:00:00 +0000 2014', delete=None, entities=Row(hashtags=[], media=[Row(display_url='pic.twitter.com/D8jl2LerkT', expanded_url='http://twitter.com/tweetsdamour_/status/536524938099064833/photo/1', id=536524925184380928, id_str='536524925184380928', indices=[126, 140], media_url='http://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', media_url_https='https://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', sizes=Row(large=Row(h=265, resize='fit', w=400), medium=Row(h=265, resize='fit', w=400), small=Row(h=225, resize='fit', w=340), thumb=Row(h=150, resize='crop', w=150)), source_status_id=536524938099064833, source_status_id_str='536524938099064833', type='photo', url='http://t.co/D8jl2LerkT')], symbols=[], trends=[], urls=[], user_mentions=[Row(id=1654219944, id_str='1654219944', indices=[3, 17], name="L'instant amoureux.♡", screen_name='tweetsdamour_')]), extended_entities=Row(media=[Row(display_url='pic.twitter.com/D8jl2LerkT', expanded_url='http://twitter.com/tweetsdamour_/status/536524938099064833/photo/1', id=536524925184380928, id_str='536524925184380928', indices=[126, 140], media_url='http://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', media_url_https='https://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', sizes=Row(large=Row(h=265, resize='fit', w=400), medium=Row(h=265, resize='fit', w=400), small=Row(h=225, resize='fit', w=340), thumb=Row(h=150, resize='crop', w=150)), source_status_id=536524938099064833, source_status_id_str='536524938099064833', type='photo', url='http://t.co/D8jl2LerkT'), Row(display_url='pic.twitter.com/D8jl2LerkT', expanded_url='http://twitter.com/tweetsdamour_/status/536524938099064833/photo/1', id=536524925096312832, id_str='536524925096312832', indices=[139, 140], media_url='http://pbs.twimg.com/media/B3Iek6WCQAAKRjq.jpg', media_url_https='https://pbs.twimg.com/media/B3Iek6WCQAAKRjq.jpg', sizes=Row(large=Row(h=1024, resize='fit', w=577), medium=Row(h=1024, resize='fit', w=577), small=Row(h=603, resize='fit', w=340), thumb=Row(h=150, resize='crop', w=150)), source_status_id=536524938099064833, source_status_id_str='536524938099064833', type='photo', url='http://t.co/D8jl2LerkT')]), favorite_count=0, favorited=False, filter_level='medium', geo=None, id=540279312520581120, id_str='540279312520581120', in_reply_to_screen_name=None, in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, lang='fr', place=None, possibly_sensitive=False, retweet_count=0, retweeted=False, retweeted_status=Row(contributors=None, coordinates=None, created_at='Sun Nov 23 14:21:28 +0000 2014', entities=Row(hashtags=[], media=[Row(display_url='pic.twitter.com/D8jl2LerkT', expanded_url='http://twitter.com/tweetsdamour_/status/536524938099064833/photo/1', id=536524925184380928, id_str='536524925184380928', indices=[107, 129], media_url='http://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', media_url_https='https://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', sizes=Row(large=Row(h=265, resize='fit', w=400), medium=Row(h=265, resize='fit', w=400), small=Row(h=225, resize='fit', w=340), thumb=Row(h=150, resize='crop', w=150)), source_status_id=None, source_status_id_str=None, type='photo', url='http://t.co/D8jl2LerkT')], symbols=[], trends=[], urls=[], user_mentions=[]), extended_entities=Row(media=[Row(display_url='pic.twitter.com/D8jl2LerkT', expanded_url='http://twitter.com/tweetsdamour_/status/536524938099064833/photo/1', id=536524925184380928, id_str='536524925184380928', indices=[107, 129], media_url='http://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', media_url_https='https://pbs.twimg.com/media/B3Iek6rCEAAAquz.jpg', sizes=Row(large=Row(h=265, resize='fit', w=400), medium=Row(h=265, resize='fit', w=400), small=Row(h=225, resize='fit', w=340), thumb=Row(h=150, resize='crop', w=150)), source_status_id=None, source_status_id_str=None, type='photo', url='http://t.co/D8jl2LerkT'), Row(display_url='pic.twitter.com/D8jl2LerkT', ex ...

# %%
import itertools
# int_num = df.count()
# print('total num=', int_num)
df.na.drop(subset=["entities"])

df.registerTempTable("tweets")
t = sqlContext.sql("SELECT distinct id,entities.hashtags FROM tweets").rdd


#related_hashtags= t.map(lambda t: map(lambda t0: t0[2], t[1])).map(lambda t: list(itertools.combinations(t, 2))).flatMap(lambda t: t).map(lambda x: ('\t'.join(unicode(i) for i in x), 1)).reduceByKey(lambda x,y: x+y).sortByKey(False).map(lambda x: '\t'.join(unicode(i) for i in x)).repartition(1)
related_hashtags= t.map(lambda t: map(lambda t0: t0[2].lower(), t[1])) \
                     .map(lambda t: list(itertools.combinations(t, 2))) \
                     .flatMap(lambda t: t) \
                     .map(lambda t: sorted(t)) \
                     .map(lambda x: '\t'.join(unicode(i) for i in x)) \
                     .map(lambda t: (t, 1)) \
                     .reduceByKey(lambda x,y: x+y) \
                     .filter(lambda t: t[1]>=min_occurs) \
                     .sortByKey(False) \
                     .map(lambda x: '\t'.join(unicode(i) for i in x)) \
                     .repartition(1)
print('here', related_hashtags)
## save stats from tweets to hdfs
related_hashtags.saveAsTextFile("%s/%s" % ("/tmp/tests/00", "related_hashtags"))
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-9-77311ab6c6dc> in <module>
#      16                      .reduceByKey(lambda x,y: x+y) \
#      17                      .filter(lambda t: t[1]>=min_occurs) \
# ---> 18                      .sortByKey(False) \
#      19                      .map(lambda x: '\t'.join(unicode(i) for i in x)) \
#      20                      .repartition(1)
#
# /usr/hdp/current/spark2-client/python/pyspark/rdd.py in sortByKey(self, ascending, numPartitions, keyfunc)
#     660         # the key-space into bins such that the bins have roughly the same
#     661         # number of (key, value) pairs falling into them
# --> 662         rddSize = self.count()
#     663         if not rddSize:
#     664             return self  # empty RDD
#
# /usr/hdp/current/spark2-client/python/pyspark/rdd.py in count(self)
#    1039         3
#    1040         """
# -> 1041         return self.mapPartitions(lambda i: [sum(1 for _ in i)]).sum()
#    1042
#    1043     def stats(self):
#
# /usr/hdp/current/spark2-client/python/pyspark/rdd.py in sum(self)
#    1030         6.0
#    1031         """
# -> 1032         return self.mapPartitions(lambda x: [sum(x)]).fold(0, operator.add)
#    1033
#    1034     def count(self):
#
# /usr/hdp/current/spark2-client/python/pyspark/rdd.py in fold(self, zeroValue, op)
#     904         # zeroValue provided to each partition is unique from the one provided
#     905         # to the final reduce call
# --> 906         vals = self.mapPartitions(func).collect()
#     907         return reduce(op, vals, zeroValue)
#     908
#
# /usr/hdp/current/spark2-client/python/pyspark/rdd.py in collect(self)
#     807         """
#     808         with SCCallSiteSync(self.context) as css:
# --> 809             port = self.ctx._jvm.PythonRDD.collectAndServe(self._jrdd.rdd())
#     810         return list(_load_from_socket(port, self._jrdd_deserializer))
#     811
#
# /usr/hdp/current/spark2-client/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
# -> 1133             answer, self.gateway_client, self.target_id, self.name)
#    1134
#    1135         for temp_arg in temp_args:
#
# /usr/hdp/current/spark2-client/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/hdp/current/spark2-client/python/lib/py4j-0.10.4-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     317                 raise Py4JJavaError(
#     318                     "An error occurred while calling {0}{1}{2}.\n".
# --> 319                     format(target_id, ".", name), value)
#     320             else:
#     321                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling z:org.apache.spark.api.python.PythonRDD.collectAndServe.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 9.0 failed 4 times, most recent failure: Lost task 0.3 in stage 9.0 (TID 21, data7201-node9.fabric.zones.eait.uq.edu.au, executor 1): org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/hdp/current/spark2-client/python/pyspark/worker.py", line 177, in main
#     process()
#   File "/usr/hdp/current/spark2-client/python/pyspark/worker.py", line 172, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 2423, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 2423, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 346, in func
#     return f(iterator)
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 1842, in combineLocally
#     merger.mergeValues(iterator)
#   File "/usr/hdp/current/spark2-client/python/pyspark/shuffle.py", line 236, in mergeValues
#     for k, v in iterator:
#   File "<ipython-input-9-77311ab6c6dc>", line 11, in <lambda>
#   File "<ipython-input-9-77311ab6c6dc>", line 10, in <lambda>
#   File "/usr/hdp/current/spark2-client/python/pyspark/sql/types.py", line 1487, in __getitem__
#     return super(Row, self).__getitem__(item)
# IndexError: tuple index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.<init>(PythonRDD.scala:234)
# 	at org.apache.spark.api.python.PythonRunner.compute(PythonRDD.scala:152)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:63)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.api.python.PairwiseRDD.compute(PythonRDD.scala:395)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:108)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:338)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	at java.lang.Thread.run(Thread.java:745)
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1517)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1505)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1504)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1504)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:814)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:814)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:814)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:1732)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1687)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:1676)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:630)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2029)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2050)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2069)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2094)
# 	at org.apache.spark.rdd.RDD$$anonfun$collect$1.apply(RDD.scala:936)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:362)
# 	at org.apache.spark.rdd.RDD.collect(RDD.scala:935)
# 	at org.apache.spark.api.python.PythonRDD$.collectAndServe(PythonRDD.scala:458)
# 	at org.apache.spark.api.python.PythonRDD.collectAndServe(PythonRDD.scala)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:280)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:745)
# Caused by: org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/usr/hdp/current/spark2-client/python/pyspark/worker.py", line 177, in main
#     process()
#   File "/usr/hdp/current/spark2-client/python/pyspark/worker.py", line 172, in process
#     serializer.dump_stream(func(split_index, iterator), outfile)
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 2423, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 2423, in pipeline_func
#     return func(split, prev_func(split, iterator))
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 346, in func
#     return f(iterator)
#   File "/usr/hdp/current/spark2-client/python/pyspark/rdd.py", line 1842, in combineLocally
#     merger.mergeValues(iterator)
#   File "/usr/hdp/current/spark2-client/python/pyspark/shuffle.py", line 236, in mergeValues
#     for k, v in iterator:
#   File "<ipython-input-9-77311ab6c6dc>", line 11, in <lambda>
#   File "<ipython-input-9-77311ab6c6dc>", line 10, in <lambda>
#   File "/usr/hdp/current/spark2-client/python/pyspark/sql/types.py", line 1487, in __getitem__
#     return super(Row, self).__getitem__(item)
# IndexError: tuple index out of range
#
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.read(PythonRDD.scala:193)
# 	at org.apache.spark.api.python.PythonRunner$$anon$1.<init>(PythonRDD.scala:234)
# 	at org.apache.spark.api.python.PythonRunner.compute(PythonRDD.scala:152)
# 	at org.apache.spark.api.python.PythonRDD.compute(PythonRDD.scala:63)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.api.python.PairwiseRDD.compute(PythonRDD.scala:395)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:323)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:287)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:96)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:108)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:338)
# 	at java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1142)
# 	at java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:617)
# 	... 1 more
